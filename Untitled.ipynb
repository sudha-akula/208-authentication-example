# %%
import plotly.express as px
import math
import plotly.graph_objects as go

# %%
# get data from plotly express
df = px.data.gapminder()
df_2007 = df[df['year']==2007]
df_2007 = df_2007.sort_values(['continent', 'country'])
df_2007.head(20)
# Out:
#                       country continent  year  lifeExp       pop  \
# 35                    Algeria    Africa  2007   72.301  33333216
# 47                     Angola    Africa  2007   42.731  12420476
# 131                     Benin    Africa  2007   56.728   8078314
# 167                  Botswana    Africa  2007   50.728   1639131
# 203              Burkina Faso    Africa  2007   52.295  14326203
# 215                   Burundi    Africa  2007   49.580   8390505
# 239                  Cameroon    Africa  2007   50.430  17696293
# 263  Central African Republic    Africa  2007   44.741   4369038
# 275                      Chad    Africa  2007   50.651  10238807
# 323                   Comoros    Africa  2007   65.152    710960
# 335          Congo, Dem. Rep.    Africa  2007   46.462  64606759
# 347               Congo, Rep.    Africa  2007   55.322   3800610
# 371             Cote d'Ivoire    Africa  2007   48.328  18013409
# ...

# %%
hover_text = []
bubble_size = []

for index, row in df_2007.iterrows():
    hover_text.append(('Country: {country}<br>'+
                      'Life Expectancy: {lifeExp}<br>'+
                      'GDP per capita: {gdp}<br>'+
                      'Population: {pop}<br>'+
                      'Year: {year}').format(country=row['country'],
                                            lifeExp=row['lifeExp'],
                                            gdp=row['gdpPercap'],
                                            pop=row['pop'],
                                            year=row['year']))
    bubble_size.append(math.sqrt(row['pop']))

# %%
df_2007['text'] = hover_text
df_2007['size'] = bubble_size
sizeref = 2.*max(df_2007['size'])/(100**2)

# %%
df_2007['continent'].unique()
# Out:
# array(['Africa', 'Americas', 'Asia', 'Europe', 'Oceania'], dtype=object)

# %%
dropdown_value = 'Europe'
#df_2007="continent == '%s'" %drp_val
df_2007 = df_2007.query("continent == '%s'" %dropdown_value)
trace0 = px.scatter(df_2007, x="gdpPercap", y="lifeExp",
	         size="pop",color="country",
                 hover_name="country", log_x=True, size_max=60)

graph_title='Bubble Chart of {}'.format(str(dropdown_value))

data = [trace0]
layout = go.Layout(
    title = graph_title
)

# Generate the figure dictionary
fig = go.Figure(data=data,layout=layout)

fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [44], in <cell line: 16>()
#      11 layout = go.Layout(
#      12     title = graph_title
#      13 )
#      15 # Generate the figure dictionary
# ---> 16 fig = go.Figure(data=data,layout=layout)
#      18 fig.show()
#
# File /opt/conda/lib/python3.8/site-packages/plotly/graph_objs/_figure.py:594, in Figure.__init__(self, data, layout, frames, skip_invalid, **kwargs)
#       5 def __init__(
#       6     self, data=None, layout=None, frames=None, skip_invalid=False, **kwargs
#       7 ):
#       8     """
#       9     Create a new :class:Figure instance
#      10
#    (...)
#     592         is invalid AND skip_invalid is False
#     593     """
# --> 594     super(Figure, self).__init__(data, layout, frames, skip_invalid, **kwargs)
#
# ...
